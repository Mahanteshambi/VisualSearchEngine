# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# !pip install mtcnn
# !pip install --upgrade cython
# !pip install --upgrade setuptools
# !pip install nmslib
# !pip install pandas
# !pip install cmake
# !pip install dlib
# !pip install imutils
# !pip install face_recognition
# Out:
# ...
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-p15rt6ct
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-p15rt6ct
# ...
#   Created wheel for keras-vggface: filename=keras_vggface-0.6-cp36-none-any.whl size=8311 sha256=17384a82dcaf5ad70c90baaadeb6de44436c31f8753d25680af53c5344acf7f8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o0o0rn3a/wheels/36/07/46/06c25ce8e9cd396dabe151ea1d8a2bc28dafcb11321c1f3a6d
# Successfully built keras-vggface
# ...
#      |████████████████████████████████| 2.3MB 2.8MB/s
# ...
# Requirement already up-to-date: cython in /usr/local/lib/python3.6/dist-packages (0.29.17)
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (46.1.3)
# ...
#      |████████████████████████████████| 13.0MB 302kB/s
# ...
#      |████████████████████████████████| 296kB 49.7MB/s
# ...
#      |████████████████████████████████| 100.2MB 98kB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/FaceProcessing/code/FeatureExtractor/
# Out:
# Cropped_face_fe.ipynb  FeatureExtraction.ipynb		 VideoProcessing.ipynb
# CroppedFaceFE.py       FeatureExtractor.py		 VideoProcessing.py
# Face_crop.ipynb        MiniCelebAFeatureExtractor.ipynb
# Face_crop.py	       MiniCelebAFeatureExtractor.py

# %%
# !python /content/gdrive/My\ Drive/FaceProcessing/code/FeatureExtractor/CroppedFaceFE.py \\
-src /content/gdrive/My\ Drive/FaceProcessing/data/face_square_images/ \\
-dst /content/gdrive/My\ Drive/FaceProcessing/code/output/ \\
-debug True \\
-model_type "vgg16"
# Out:
# Using TensorFlow backend.
# 2020-05-02 18:59:49.649050: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib
# 1190
# Processed 1190 faces in [379.247] seconds
# tcmalloc: large alloc 1433026560 bytes == 0x1bd40000 @  0x7f4fa3e401e7 0x7f4fa19a85e1 0x7f4fa1a0d8e0 0x7f4fa1a9b447 0x50ac25 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40 0x7f4fa3a3db97 0x5b2fda
# 2020-05-02 19:06:11.933302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-02 19:06:11.935231: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...
