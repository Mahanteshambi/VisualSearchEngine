# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# !pip install mtcnn
# !pip install --upgrade cython
# !pip install --upgrade setuptools
# !pip install nmslib
# !pip install pandas
# !pip install cmake
# !pip install dlib
# !pip install imutils
# !pip install face_recognition
# Out:
# ...
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-9ep4d4bx
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-9ep4d4bx
# ...
#   Created wheel for keras-vggface: filename=keras_vggface-0.6-cp36-none-any.whl size=8311 sha256=66a98288fe58dfd3b3236650932fc464c9d85cd3201cac87be2391dbceda9300
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yt0227ct/wheels/36/07/46/06c25ce8e9cd396dabe151ea1d8a2bc28dafcb11321c1f3a6d
# Successfully built keras-vggface
# ...
#      |████████████████████████████████| 2.3MB 9.6MB/s
# ...
# Requirement already up-to-date: cython in /usr/local/lib/python3.6/dist-packages (0.29.17)
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (46.1.3)
# ...
#      |████████████████████████████████| 13.0MB 1.5MB/s
# ...
#      |████████████████████████████████| 296kB 55.1MB/s
# ...
#      |████████████████████████████████| 100.2MB 74kB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/FaceProcessing/
# !ls /content/gdrive/My\ Drive/FaceProcessing/code/
# Out:
# code		     processed_images	      requirements.txt
# preprocessed_images  processed_square_images  steps.txt
# FaceFeatures.hnsw     FeatureExtraction.ipynb  Untitled1.ipynb
# FaceProcessing.ipynb  FeatureExtractor.py      Untitled2.ipynb
# FaceSearch.ipynb      prepare_data	       Untitled.ipynb

# %%
# !python /content/gdrive/My\ Drive/FaceProcessing/code/FeatureExtractor.py -model_type "vgg16" -debug False -images /content/gdrive/My\ Drive/FaceProcessing/processed_square_images/
# Out:
# Using TensorFlow backend.
# 2020-05-01 19:39:20.432524: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib
# 2020-05-01 19:39:21.844064: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-01 19:39:21.892900: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-01 19:39:21.893515: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# ...

# %%
# !python /content/gdrive/My\ Drive/FaceProcessing/code/FeatureExtractor.py -model_type "resnet50" -debug False -images /content/gdrive/My\ Drive/FaceProcessing/processed_square_images/
# Out:
# Using TensorFlow backend.
# 2020-05-01 20:52:56.585979: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib
# 2020-05-01 20:52:57.907537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-01 20:52:57.933783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-01 20:52:57.934378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# ...
