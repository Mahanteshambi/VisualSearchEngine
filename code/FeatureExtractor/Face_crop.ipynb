# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# !pip install mtcnn
# !pip install --upgrade cython
# !pip install --upgrade setuptools
# !pip install nmslib
# !pip install pandas
# !pip install cmake
# !pip install dlib
# !pip install imutils
# !pip install face_recognition
# Out:
# ...
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-1g8ul_bw
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-1g8ul_bw
# ...
#   Created wheel for keras-vggface: filename=keras_vggface-0.6-cp36-none-any.whl size=8311 sha256=5c9ec004e9c9c897a826656b6b9dad40e8f10b9e1d61d365c1360270a65e92f7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4h8y_14g/wheels/36/07/46/06c25ce8e9cd396dabe151ea1d8a2bc28dafcb11321c1f3a6d
# Successfully built keras-vggface
# ...
#      |████████████████████████████████| 2.3MB 2.8MB/s
# ...
# Requirement already up-to-date: cython in /usr/local/lib/python3.6/dist-packages (0.29.17)
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (46.1.3)
# ...
#      |████████████████████████████████| 13.0MB 302kB/s
# ...
#      |████████████████████████████████| 296kB 45.4MB/s
# ...
#      |████████████████████████████████| 100.2MB 100kB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/FaceProcessing/data/face_square_images/
# Out:
# 0_000000.jpg  0_000013.jpg

# %%
# !python /content/gdrive/My\ Drive/FaceProcessing/code/FeatureExtractor/Face_crop.py -src /content/gdrive/My\ Drive/FaceProcessing/processed_square_images/ -dst /content/gdrive/My\ Drive/FaceProcessing/data/face_square_images/
# Out:
# Using TensorFlow backend.
# 2020-05-02 18:37:46.244646: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-02 18:37:47.762813: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-02 18:37:47.764393: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-05-02 18:37:47.764436: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c338cbaaf462): /proc/driver/nvidia/version does not exist
# 2020-05-02 18:37:47.769309: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200000000 Hz
# 2020-05-02 18:37:47.769529: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x288b100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
