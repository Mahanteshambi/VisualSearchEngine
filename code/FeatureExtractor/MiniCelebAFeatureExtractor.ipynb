# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# !pip install mtcnn
# !pip install --upgrade cython
# !pip install --upgrade setuptools
# !pip install nmslib
# !pip install pandas
# !pip install cmake
# !pip install dlib
# !pip install imutils
# !pip install face_recognition
# Out:
# ...
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-zh95i3vq
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-zh95i3vq
# ...
#   Created wheel for keras-vggface: filename=keras_vggface-0.6-cp36-none-any.whl size=8311 sha256=dc11b4f21aa439857dcdafabbb765e2c341e783ee5204be32d6676b10c8fe5c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-31s5_qw3/wheels/36/07/46/06c25ce8e9cd396dabe151ea1d8a2bc28dafcb11321c1f3a6d
# Successfully built keras-vggface
# ...
#      |████████████████████████████████| 2.3MB 6.1MB/s
# ...
# Requirement already up-to-date: cython in /usr/local/lib/python3.6/dist-packages (0.29.17)
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (46.1.3)
# ...
#      |████████████████████████████████| 13.0MB 222kB/s
# ...
#      |████████████████████████████████| 296kB 41.6MB/s
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/FaceProcessing/code/FeatureExtractor
# Out:
# ls: cannot access '/content/gdrive/My Drive/FaceProcessing/code/FeatureExtractor': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# !python /content/gdrive/My\ Drive/FaceProcessing/code/FeatureExtractor/MiniCelebAFeatureExtractor.py -debug True -src /content/gdrive/My\ Drive/FaceProcessing/data/miniCelebA/ -dst /content/gdrive/My\ Drive/FaceProcessing/code/output/ -model_type "vgg16"
# Out:
# Mounted at /content/gdrive
# Using TensorFlow backend.
# 2020-05-02 12:33:47.872043: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib
# In train folder of 0
# 100
# In val folder of 0
# 30
# In test folder of 0
# 30
# In train folder of 1
# 100
# In val folder of 1
# 30
# In test folder of 1
# 30
# In train folder of 2
# 100
# In val folder of 2
# 30
# In test folder of 2
# 30
# In train folder of 3
# 100
# In val folder of 3
# 30
# In test folder of 3
# 30
# In train folder of 4
# 100
# In val folder of 4
# 30
# In test folder of 4
# 30
# In train folder of 5
# 100
# In val folder of 5
# 30
# In test folder of 5
# 30
# In train folder of 6
# 100
# In val folder of 6
# 30
# In test folder of 6
# 30
# ...
